# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import matplotlib as mpl 
mpl.rcParams['figure.dpi'] = 400 # figure dots per inch
# %matplotlib inline

import seaborn as sns
sns.set()

from datetime import datetime, timedelta

# %%
# Load transactions (all data including March)  
transactions_df = pd.read_pickle('Data/Processed/transactions_to_split.pickle')
transactions_df.head()
# Out:
#                                             msno        payment_method_id  \
# 1   AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=     payment_method_id_41
# 10  bQkbrEPdMfVfdsoz0RoWSmgYpHJuhRqtIml7aRUrFL8=  payment_method_id_other
# 24  qNpZJ7gsMPAFSvc5V3kgqtFfUQU2SZe7XSUYOAfqtoA=     payment_method_id_40
# 26  WnxdSgeK3Vg4BIaioJQYilnL+E1SDxq+PZIwmmfTwgM=     payment_method_id_34
# 27  ir1jh/vWZ932FpSC2WeMxdOHQ+OkuUo3ZPQs8Ms4J9g=     payment_method_id_34
#
#     payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 1                  30              149                 149              1
# 10                 30              149                 149              1
# 24                 30              149                 149              1
# 26                  0                0                 149              1
# 27                  0                0                 149              1
#
#     transaction_date  membership_expire_date  is_cancel transaction_date_dt  \
# 1           20150930                20151031          0          2015-09-30
# 10          20150930                20151121          0          2015-09-30
# 24          20151001                20151101          0          2015-10-01
# 26          20150930                20151031          0          2015-09-30
# 27          20150930                20151031          0          2015-09-30
#
#    membership_expire_date_dt transaction_date_day membership_expire_date_day  \
# 1                 2015-10-31                  Wed                        Sat
# 10                2015-11-21                  Wed                        Sat
# 24                2015-11-01                  Thu                        Sun
# 26                2015-10-31                  Wed                        Sat
# 27                2015-10-31                  Wed                        Sat
#
#    transaction_date_month membership_expire_date_month  transaction_date_year  \
# 1                     Sep                          Oct                   2015
# 10                    Sep                          Nov                   2015
# 24                    Oct                          Nov                   2015
# 26                    Sep                          Oct                   2015
# 27                    Sep                          Oct                   2015
#
#     membership_expire_date_year  plan_duration  credit transaction_credit
# 1                          2015           31.0       0               even
# 10                         2015           52.0       0               even
# 24                         2015           31.0       0               even
# 26                         2015           31.0     149             credit
# 27                         2015           31.0     149             credit

# %%
transactions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13664286 entries, 1 to 22974713
# Data columns (total 20 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   msno                          object
#  1   payment_method_id             object
#  2   payment_plan_days             int16
#  3   plan_list_price               int16
#  4   actual_amount_paid            int16
#  5   is_auto_renew                 int16
#  6   transaction_date              int64
#  7   membership_expire_date        int64
#  8   is_cancel                     int16
#  9   transaction_date_dt           datetime64[ns]
#  10  membership_expire_date_dt     datetime64[ns]
#  11  transaction_date_day          object
#  12  membership_expire_date_day    object
#  13  transaction_date_month        object
#  14  membership_expire_date_month  object
#  15  transaction_date_year         int64
#  16  membership_expire_date_year   int64
#  17  plan_duration                 float64
#  18  credit                        int16
#  19  transaction_credit            object
# dtypes: datetime64[ns](2), float64(1), int16(6), int64(4), object(7)
# memory usage: 1.7+ GB

# %% [markdown]
# ## Generate Validation Set

# %% [markdown]
# Current day is March 1st, we consider members which expiration date is in February and potentially churn in March.
# Therefore, we take transactions until the end of February - this will serve as Validation dataset.

# %%
current_day = datetime(2017, 3, 1)
transactions_df = transactions_df[(transactions_df['transaction_date_dt'] < current_day) &
                                 (transactions_df['membership_expire_date_dt'] < current_day)].reset_index(drop=True)
transactions_df.head()
# Out:
#                                            msno        payment_method_id  \
# 0  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=     payment_method_id_41
# 1  bQkbrEPdMfVfdsoz0RoWSmgYpHJuhRqtIml7aRUrFL8=  payment_method_id_other
# 2  qNpZJ7gsMPAFSvc5V3kgqtFfUQU2SZe7XSUYOAfqtoA=     payment_method_id_40
# 3  WnxdSgeK3Vg4BIaioJQYilnL+E1SDxq+PZIwmmfTwgM=     payment_method_id_34
# 4  ir1jh/vWZ932FpSC2WeMxdOHQ+OkuUo3ZPQs8Ms4J9g=     payment_method_id_34
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              149                 149              1
# 1                 30              149                 149              1
# 2                 30              149                 149              1
# 3                  0                0                 149              1
# 4                  0                0                 149              1
#
#    transaction_date  membership_expire_date  is_cancel transaction_date_dt  \
# 0          20150930                20151031          0          2015-09-30
# 1          20150930                20151121          0          2015-09-30
# 2          20151001                20151101          0          2015-10-01
# 3          20150930                20151031          0          2015-09-30
# 4          20150930                20151031          0          2015-09-30
#
#   membership_expire_date_dt transaction_date_day membership_expire_date_day  \
# 0                2015-10-31                  Wed                        Sat
# 1                2015-11-21                  Wed                        Sat
# 2                2015-11-01                  Thu                        Sun
# 3                2015-10-31                  Wed                        Sat
# 4                2015-10-31                  Wed                        Sat
#
#   transaction_date_month membership_expire_date_month  transaction_date_year  \
# 0                    Sep                          Oct                   2015
# 1                    Sep                          Nov                   2015
# 2                    Oct                          Nov                   2015
# 3                    Sep                          Oct                   2015
# 4                    Sep                          Oct                   2015
#
#    membership_expire_date_year  plan_duration  credit transaction_credit
# 0                         2015           31.0       0               even
# 1                         2015           52.0       0               even
# 2                         2015           31.0       0               even
# 3                         2015           31.0     149             credit
# 4                         2015           31.0     149             credit

# %%
transactions_df.shape
# Out:
# (13664092, 20)

# %%
transactions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13664092 entries, 0 to 13664091
# Data columns (total 20 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   msno                          object
#  1   payment_method_id             object
#  2   payment_plan_days             int16
#  3   plan_list_price               int16
#  4   actual_amount_paid            int16
#  5   is_auto_renew                 int16
#  6   transaction_date              int64
#  7   membership_expire_date        int64
#  8   is_cancel                     int16
#  9   transaction_date_dt           datetime64[ns]
#  10  membership_expire_date_dt     datetime64[ns]
#  11  transaction_date_day          object
#  12  membership_expire_date_day    object
#  13  transaction_date_month        object
#  14  membership_expire_date_month  object
#  15  transaction_date_year         int64
#  16  membership_expire_date_year   int64
#  17  plan_duration                 float64
#  18  credit                        int16
#  19  transaction_credit            object
# dtypes: datetime64[ns](2), float64(1), int16(6), int64(4), object(7)
# memory usage: 1.6+ GB

# %%
transactions_df.describe()
# Out:
#        payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# count       1.366409e+07     1.366409e+07        1.366409e+07   1.366409e+07
# mean        2.992232e+01     1.317256e+02        1.362604e+02   9.046988e-01
# std         1.756205e+01     7.888564e+01        7.586591e+01   2.936305e-01
# min         0.000000e+00     0.000000e+00        0.000000e+00   0.000000e+00
# 25%         3.000000e+01     9.900000e+01        9.900000e+01   1.000000e+00
# 50%         3.000000e+01     1.490000e+02        1.490000e+02   1.000000e+00
# 75%         3.000000e+01     1.490000e+02        1.490000e+02   1.000000e+00
# max         4.500000e+02     2.000000e+03        2.000000e+03   1.000000e+00
#
#        transaction_date  membership_expire_date     is_cancel  \
# count      1.366409e+07            1.366409e+07  1.366409e+07
# mean       2.015808e+07            2.015916e+07  1.787320e-02
# std        5.617442e+03            6.083026e+03  1.324906e-01
# min        2.015010e+07            2.015010e+07  0.000000e+00
# 25%        2.015103e+07            2.015121e+07  0.000000e+00
# 50%        2.016050e+07            2.016061e+07  0.000000e+00
# 75%        2.016093e+07            2.016103e+07  0.000000e+00
# max        2.017023e+07            2.017023e+07  1.000000e+00
#
#        transaction_date_year  membership_expire_date_year  plan_duration  \
# count           1.366409e+07                 1.366409e+07   1.366409e+07
# mean            2.015740e+03                 2.015850e+03   3.447802e+01
# std             5.704844e-01                 6.231541e-01   3.731116e+01
# min             2.015000e+03                 2.015000e+03   0.000000e+00
# 25%             2.015000e+03                 2.015000e+03   3.000000e+01
# 50%             2.016000e+03                 2.016000e+03   3.100000e+01
# 75%             2.016000e+03                 2.016000e+03   3.100000e+01
# max             2.017000e+03                 2.017000e+03   7.830000e+02
#
#              credit
# count  1.366409e+07
# mean   4.534807e+00
# std    3.257363e+01
# min   -6.990000e+02
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.788000e+03

# %%
# Time-relative features
transactions_df['days_since_last_transaction_date'] = current_day - transactions_df['transaction_date_dt']
transactions_df['days_since_last_transaction_date'] = transactions_df['days_since_last_transaction_date'].astype('timedelta64[D]')
transactions_df['days_since_membership_expire_date'] = current_day - transactions_df['membership_expire_date_dt']
transactions_df['days_since_membership_expire_date'] = transactions_df['days_since_membership_expire_date'].astype('timedelta64[D]')

# %%
transactions_df[['msno',
                 'transaction_date_dt', 
                 'days_since_last_transaction_date',
                 'membership_expire_date_dt', 
                 'days_since_membership_expire_date',
                 'is_auto_renew']].sort_values(by='msno').head()
# Out:
#                                                   msno transaction_date_dt  \
# 37103     +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=          2017-01-15
# 11365513  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=          2016-12-15
# 950309    +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=          2016-11-16
# 1834581   +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=          2016-07-26
# 10438013  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=          2015-04-26
#
#           days_since_last_transaction_date membership_expire_date_dt  \
# 37103                                 45.0                2017-02-15
# 11365513                              76.0                2017-01-15
# 950309                               105.0                2016-12-15
# 1834581                              218.0                2016-08-26
# 10438013                             675.0                2015-05-26
#
#           days_since_membership_expire_date  is_auto_renew
# 37103                                  14.0              1
# 11365513                               45.0              1
# 950309                                 76.0              1
# 1834581                               187.0              1
# 10438013                              645.0              1

# %%
transactions_df['expired_and_not_auto_renew'] = np.where(
    (transactions_df.is_auto_renew == 0) & (transactions_df.days_since_membership_expire_date > 0), 1, 0
).astype(np.int8)
transactions_df['expired_and_not_auto_renew'].value_counts()
# Out:
# 0    12361888
# 1     1302204
# Name: expired_and_not_auto_renew, dtype: int64

# %% [markdown]
# Create features summarizing the last transaction:

# %%
transactions_df_sorted = transactions_df.sort_values(['msno', 'transaction_date_dt'], 
                                                     ascending=False).reset_index(drop = True)
transactions_df_sorted
# Out:
#                                                   msno     payment_method_id  \
# 0         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# 1         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# 2         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# 3         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# 4         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# ...                                                ...                   ...
# 13664087  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=  payment_method_id_41
# 13664088  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=  payment_method_id_41
# 13664089  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=  payment_method_id_41
# 13664090  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=  payment_method_id_41
# 13664091  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=  payment_method_id_41
#
#           payment_plan_days  plan_list_price  actual_amount_paid  \
# 0                        30               99                  99
# 1                        30               99                  99
# 2                        30               99                  99
# 3                        30               99                  99
# 4                        30               99                  99
# ...                     ...              ...                 ...
# 13664087                 30              149                 149
# 13664088                 30              149                 149
# 13664089                 30               99                  99
# 13664090                 30               99                  99
# 13664091                 30               99                  99
#
#           is_auto_renew  transaction_date  membership_expire_date  is_cancel  \
# 0                     1          20170202                20170202          1
# 1                     1          20170104                20170204          0
# 2                     1          20161204                20170104          0
# 3                     1          20161104                20161204          0
# 4                     1          20161004                20161104          0
# ...                 ...               ...                     ...        ...
# 13664087              1          20150226                20150326          0
# 13664088              1          20150126                20150226          0
# 13664089              1          20170115                20170215          0
# 13664090              1          20161215                20170115          0
# 13664091              1          20161116                20161215          0
#
#          transaction_date_dt  ... transaction_date_month  \
# 0                 2017-02-02  ...                    Feb
# 1                 2017-01-04  ...                    Jan
# 2                 2016-12-04  ...                    Dec
# 3                 2016-11-04  ...                    Nov
# 4                 2016-10-04  ...                    Oct
# ...                      ...  ...                    ...
# 13664087          2015-02-26  ...                    Feb
# 13664088          2015-01-26  ...                    Jan
# 13664089          2017-01-15  ...                    Jan
# 13664090          2016-12-15  ...                    Dec
# 13664091          2016-11-16  ...                    Nov
#
#          membership_expire_date_month transaction_date_year  \
# 0                                 Feb                  2017
# 1                                 Feb                  2017
# 2                                 Jan                  2016
# 3                                 Dec                  2016
# 4                                 Nov                  2016
# ...                               ...                   ...
# 13664087                          Mar                  2015
# 13664088                          Feb                  2015
# 13664089                          Feb                  2017
# 13664090                          Jan                  2016
# 13664091                          Dec                  2016
#
#          membership_expire_date_year plan_duration  credit  \
# 0                               2017           0.0       0
# 1                               2017          31.0       0
# 2                               2017          31.0       0
# 3                               2016          30.0       0
# 4                               2016          31.0       0
# ...                              ...           ...     ...
# 13664087                        2015          28.0       0
# 13664088                        2015          31.0       0
# 13664089                        2017          31.0       0
# 13664090                        2017          31.0       0
# 13664091                        2016          29.0       0
#
#           transaction_credit  days_since_last_transaction_date  \
# 0                       even                              27.0
# 1                       even                              56.0
# 2                       even                              87.0
# 3                       even                             117.0
# 4                       even                             148.0
# ...                      ...                               ...
# 13664087                even                             734.0
# 13664088                even                             765.0
# 13664089                even                              45.0
# 13664090                even                              76.0
# 13664091                even                             105.0
#
#           days_since_membership_expire_date expired_and_not_auto_renew
# 0                                      27.0                          0
# 1                                      25.0                          0
# 2                                      56.0                          0
# 3                                      87.0                          0
# 4                                     117.0                          0
# ...                                     ...                        ...
# 13664087                              706.0                          0
# 13664088                              734.0                          0
# 13664089                               14.0                          0
# 13664090                               45.0                          0
# 13664091                               76.0                          0
#
# [13664092 rows x 23 columns]

# %%
last_transactions_df = transactions_df_sorted.drop_duplicates(subset='msno', keep='first').reset_index(drop=True)
last_transactions_df.columns = last_transactions_df.columns + '_last'
last_transactions_df = last_transactions_df.rename(columns={'msno_last': 'msno'})
last_transactions_df
# Out:
#                                                 msno   payment_method_id_last  \
# 0       zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=     payment_method_id_41
# 1       zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=  payment_method_id_other
# 2       zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=     payment_method_id_41
# 3       zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=     payment_method_id_41
# 4       zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=     payment_method_id_41
# ...                                              ...                      ...
# 934528  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=     payment_method_id_38
# 934529  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=     payment_method_id_41
# 934530  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=     payment_method_id_41
# 934531  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=     payment_method_id_41
# 934532  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=     payment_method_id_41
#
#         payment_plan_days_last  plan_list_price_last  actual_amount_paid_last  \
# 0                           30                    99                       99
# 1                          100                   480                      480
# 2                           30                    99                       99
# 3                           30                    99                       99
# 4                           30                    99                       99
# ...                        ...                   ...                      ...
# 934528                      30                   149                      149
# 934529                      30                   149                      149
# 934530                      30                   149                      149
# 934531                      30                   149                      149
# 934532                      30                    99                       99
#
#         is_auto_renew_last  transaction_date_last  \
# 0                        1               20170202
# 1                        0               20161022
# 2                        1               20170118
# 3                        1               20170126
# 4                        1               20161111
# ...                    ...                    ...
# 934528                   0               20170124
# 934529                   1               20170120
# 934530                   1               20170115
# 934531                   1               20170126
# 934532                   1               20170115
#
#         membership_expire_date_last  is_cancel_last transaction_date_dt_last  \
# 0                          20170202               1               2017-02-02
# 1                          20170130               0               2016-10-22
# 2                          20170218               0               2017-01-18
# 3                          20170226               0               2017-01-26
# 4                          20170209               1               2016-11-11
# ...                             ...             ...                      ...
# 934528                     20170223               0               2017-01-24
# 934529                     20170220               0               2017-01-20
# 934530                     20170215               0               2017-01-15
# 934531                     20170226               0               2017-01-26
# 934532                     20170215               0               2017-01-15
#
#         ... transaction_date_month_last membership_expire_date_month_last  \
# 0       ...                         Feb                               Feb
# 1       ...                         Oct                               Jan
# 2       ...                         Jan                               Feb
# 3       ...                         Jan                               Feb
# 4       ...                         Nov                               Feb
# ...     ...                         ...                               ...
# 934528  ...                         Jan                               Feb
# 934529  ...                         Jan                               Feb
# 934530  ...                         Jan                               Feb
# 934531  ...                         Jan                               Feb
# 934532  ...                         Jan                               Feb
#
#        transaction_date_year_last membership_expire_date_year_last  \
# 0                            2017                             2017
# 1                            2016                             2017
# 2                            2017                             2017
# 3                            2017                             2017
# 4                            2016                             2017
# ...                           ...                              ...
# 934528                       2017                             2017
# 934529                       2017                             2017
# 934530                       2017                             2017
# 934531                       2017                             2017
# 934532                       2017                             2017
#
#        plan_duration_last  credit_last  transaction_credit_last  \
# 0                     0.0            0                     even
# 1                   100.0            0                     even
# 2                    31.0            0                     even
# 3                    31.0            0                     even
# 4                    90.0            0                     even
# ...                   ...          ...                      ...
# 934528               30.0            0                     even
# 934529               31.0            0                     even
# 934530               31.0            0                     even
# 934531               31.0            0                     even
# 934532               31.0            0                     even
#
#         days_since_last_transaction_date_last  \
# 0                                        27.0
# 1                                       130.0
# 2                                        42.0
# 3                                        34.0
# 4                                       110.0
# ...                                       ...
# 934528                                   36.0
# 934529                                   40.0
# 934530                                   45.0
# 934531                                   34.0
# 934532                                   45.0
#
#         days_since_membership_expire_date_last expired_and_not_auto_renew_last
# 0                                         27.0                               0
# 1                                         30.0                               1
# 2                                         11.0                               0
# 3                                          3.0                               0
# 4                                         20.0                               0
# ...                                        ...                             ...
# 934528                                     6.0                               1
# 934529                                     9.0                               0
# 934530                                    14.0                               0
# 934531                                     3.0                               0
# 934532                                    14.0                               0
#
# [934533 rows x 23 columns]

# %% [markdown]
# Let's create other features by grouping and aggregating:

# %%
transactions_sum_df = transactions_df.copy()
transactions_sum_df.columns
# Out:
# Index(['msno', 'payment_method_id', 'payment_plan_days', 'plan_list_price',
#        'actual_amount_paid', 'is_auto_renew', 'transaction_date',
#        'membership_expire_date', 'is_cancel', 'transaction_date_dt',
#        'membership_expire_date_dt', 'transaction_date_day',
#        'membership_expire_date_day', 'transaction_date_month',
#        'membership_expire_date_month', 'transaction_date_year',
#        'membership_expire_date_year', 'plan_duration', 'credit',
#        'transaction_credit', 'days_since_last_transaction_date',
#        'days_since_membership_expire_date', 'expired_and_not_auto_renew'],
#       dtype='object')

# %%
to_drop = ['payment_method_id',
           'transaction_date',
           'membership_expire_date', 
           'transaction_date_dt', 
           'membership_expire_date_dt',
           'days_since_last_transaction_date',
           'days_since_membership_expire_date',
           ]
transactions_sum_df.drop(to_drop, axis=1, inplace=True)

# %%
transactions_sum_df = transactions_sum_df.groupby('msno').sum().reset_index()
transactions_sum_df.columns = transactions_sum_df.columns + '_sum' 
transactions_sum_df = transactions_sum_df.rename(columns={'msno_sum': 'msno'})

# %%
transactions_sum_df['overall_credit'] = np.where(transactions_sum_df['credit_sum'] == 0, 
                                             'even', np.where(transactions_sum_df['credit_sum'] > 0, 
                                                              'credit', 'debit'))

# %%
transactions_sum_df['paid_per_day'] = transactions_sum_df['actual_amount_paid_sum'] / transactions_sum_df['plan_duration_sum']

# %%
transactions_sum_df.head()
# Out:
#                                            msno  payment_plan_days_sum  \
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                     90
# 1  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                    720
# 2  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                    330
# 3  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                    330
# 4  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                    517
#
#    plan_list_price_sum  actual_amount_paid_sum  is_auto_renew_sum  \
# 0                  297                     297                  3
# 1                 3576                    3725                 25
# 2                 1639                    1639                 11
# 3                 1639                    1639                 11
# 4                 2414                    2414                  0
#
#    is_cancel_sum  transaction_date_year_sum  membership_expire_date_year_sum  \
# 0              0                       6049                             6050
# 1              0                      50389                            50391
# 2              0                      22177                            22178
# 3              0                      22177                            22178
# 4              0                      30236                            30238
#
#    plan_duration_sum  credit_sum  expired_and_not_auto_renew_sum  \
# 0               91.0           0                               0
# 1              762.0         149                               0
# 2              337.0           0                               0
# 3              337.0           0                               0
# 4              550.0           0                              15
#
#   overall_credit  paid_per_day
# 0           even      3.263736
# 1         credit      4.888451
# 2           even      4.863501
# 3           even      4.863501
# 4           even      4.389091

# %%
transactions_sum_df.shape
# Out:
# (934533, 13)

# %%
transactions_count_df = transactions_df.groupby('msno')['is_cancel'].count().reset_index()
transactions_count_df.rename(columns={'is_cancel': 'transactions_count'}, inplace=True)
transactions_count_df.shape
# Out:
# (934533, 2)

# %%
transactions_sum_df = pd.merge(transactions_sum_df, transactions_count_df, on='msno', how='inner')
transactions_sum_df['amount_paid_per_transaction'] = transactions_sum_df['actual_amount_paid_sum'] / transactions_sum_df['transactions_count']
transactions_sum_df.head()
# Out:
#                                            msno  payment_plan_days_sum  \
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                     90
# 1  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                    720
# 2  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                    330
# 3  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                    330
# 4  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                    517
#
#    plan_list_price_sum  actual_amount_paid_sum  is_auto_renew_sum  \
# 0                  297                     297                  3
# 1                 3576                    3725                 25
# 2                 1639                    1639                 11
# 3                 1639                    1639                 11
# 4                 2414                    2414                  0
#
#    is_cancel_sum  transaction_date_year_sum  membership_expire_date_year_sum  \
# 0              0                       6049                             6050
# 1              0                      50389                            50391
# 2              0                      22177                            22178
# 3              0                      22177                            22178
# 4              0                      30236                            30238
#
#    plan_duration_sum  credit_sum  expired_and_not_auto_renew_sum  \
# 0               91.0           0                               0
# 1              762.0         149                               0
# 2              337.0           0                               0
# 3              337.0           0                               0
# 4              550.0           0                              15
#
#   overall_credit  paid_per_day  transactions_count  \
# 0           even      3.263736                   3
# 1         credit      4.888451                  25
# 2           even      4.863501                  11
# 3           even      4.863501                  11
# 4           even      4.389091                  15
#
#    amount_paid_per_transaction
# 0                    99.000000
# 1                   149.000000
# 2                   149.000000
# 3                   149.000000
# 4                   160.933333

# %%
transactions_sum_df.shape
# Out:
# (934533, 15)

# %%
transactions_mean_df = transactions_df.copy()
transactions_mean_df.columns
# Out:
# Index(['msno', 'payment_method_id', 'payment_plan_days', 'plan_list_price',
#        'actual_amount_paid', 'is_auto_renew', 'transaction_date',
#        'membership_expire_date', 'is_cancel', 'transaction_date_dt',
#        'membership_expire_date_dt', 'transaction_date_day',
#        'membership_expire_date_day', 'transaction_date_month',
#        'membership_expire_date_month', 'transaction_date_year',
#        'membership_expire_date_year', 'plan_duration', 'credit',
#        'transaction_credit', 'days_since_last_transaction_date',
#        'days_since_membership_expire_date', 'expired_and_not_auto_renew'],
#       dtype='object')

# %%
to_drop = ['payment_method_id',
           'transaction_date',
           'membership_expire_date', 
           'transaction_date_dt', 
           'membership_expire_date_dt',
           'transaction_date_day',
           'membership_expire_date_day', 
           'transaction_date_month',
           'membership_expire_date_month', 
           'transaction_date_year',
           'membership_expire_date_year']
transactions_mean_df.drop(to_drop, axis=1, inplace=True)

# %%
transactions_mean_df = transactions_mean_df.groupby('msno').mean().reset_index()
transactions_mean_df.columns = transactions_mean_df.columns + '_mean' 
transactions_mean_df = transactions_mean_df.rename(columns={'msno_mean': 'msno'})

transactions_mean_df.head()
# Out:
#                                            msno  payment_plan_days_mean  \
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=               30.000000
# 1  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=               28.800000
# 2  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=               30.000000
# 3  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=               30.000000
# 4  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=               34.466667
#
#    plan_list_price_mean  actual_amount_paid_mean  is_auto_renew_mean  \
# 0             99.000000                99.000000                 1.0
# 1            143.040000               149.000000                 1.0
# 2            149.000000               149.000000                 1.0
# 3            149.000000               149.000000                 1.0
# 4            160.933333               160.933333                 0.0
#
#    is_cancel_mean  plan_duration_mean  credit_mean  \
# 0             0.0           30.333333         0.00
# 1             0.0           30.480000         5.96
# 2             0.0           30.636364         0.00
# 3             0.0           30.636364         0.00
# 4             0.0           36.666667         0.00
#
#    days_since_last_transaction_date_mean  \
# 0                              75.333333
# 1                             400.320000
# 2                             198.000000
# 3                             193.000000
# 4                             339.933333
#
#    days_since_membership_expire_date_mean  expired_and_not_auto_renew_mean
# 0                               45.000000                              0.0
# 1                              369.840000                              0.0
# 2                              167.363636                              0.0
# 3                              162.363636                              0.0
# 4                              303.266667                              1.0

# %% [markdown]
# transactions_median_df = transactions_df.copy()
# transactions_median_df = transactions_median_df.groupby('msno').median().reset_index()
# transactions_median_df.columns = transactions_median_df.columns + '_median'
# transactions_median_df = transactions_median_df.rename(columns={'msno_median': 'msno'})
#
# transactions_median_df.head()

# %%
(last_transactions_df.shape, 
 transactions_sum_df.shape, 
 transactions_mean_df.shape)
# Out:
# ((934533, 23), (934533, 15), (934533, 11))

# %%
numerical_columns_mean = [col for col in transactions_mean_df.columns if transactions_mean_df[col].dtype != 'object']
numerical_columns_mean
# Out:
# ['payment_plan_days_mean',
#  'plan_list_price_mean',
#  'actual_amount_paid_mean',
#  'is_auto_renew_mean',
#  'is_cancel_mean',
#  'plan_duration_mean',
#  'credit_mean',
#  'days_since_last_transaction_date_mean',
#  'days_since_membership_expire_date_mean',
#  'expired_and_not_auto_renew_mean']

# %%
numerical_columns_last = [col for col in last_transactions_df.columns if last_transactions_df[col].dtype != 'object']
numerical_columns_last
# Out:
# ['payment_plan_days_last',
#  'plan_list_price_last',
#  'actual_amount_paid_last',
#  'is_auto_renew_last',
#  'transaction_date_last',
#  'membership_expire_date_last',
#  'is_cancel_last',
#  'transaction_date_dt_last',
#  'membership_expire_date_dt_last',
#  'transaction_date_year_last',
#  'membership_expire_date_year_last',
#  'plan_duration_last',
#  'credit_last',
#  'days_since_last_transaction_date_last',
#  'days_since_membership_expire_date_last',
#  'expired_and_not_auto_renew_last']

# %%
to_remove = ['transaction_date_last',
             'membership_expire_date_last',
             'transaction_date_dt_last',
             'membership_expire_date_dt_last',
             'transaction_date_year_last',
             'membership_expire_date_year_last']
for element in to_remove:
    numerical_columns_last.remove(element)
    
numerical_columns_last
# Out:
# ['payment_plan_days_last',
#  'plan_list_price_last',
#  'actual_amount_paid_last',
#  'is_auto_renew_last',
#  'is_cancel_last',
#  'plan_duration_last',
#  'credit_last',
#  'days_since_last_transaction_date_last',
#  'days_since_membership_expire_date_last',
#  'expired_and_not_auto_renew_last']

# %%
df1 = last_transactions_df[['msno'] + numerical_columns_last].sort_values(by='msno').set_index('msno')
df1
# Out:
#                                               payment_plan_days_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                      30
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                      30
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                      30
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                      30
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                      30
# ...                                                              ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                      30
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                      30
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                      30
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                     100
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                      30
#
#                                               plan_list_price_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                    99
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                   149
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                   149
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                   149
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                   149
# ...                                                            ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                    99
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                    99
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                    99
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                   480
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                    99
#
#                                               actual_amount_paid_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                       99
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                      149
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                      149
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                      149
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                      149
# ...                                                               ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                       99
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                       99
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                       99
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                      480
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                       99
#
#                                               is_auto_renew_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                   1
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                   1
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                   1
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                   1
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                   0
# ...                                                          ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                   1
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                   1
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                   1
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                   0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                   1
#
#                                               is_cancel_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=               0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=               0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=               0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=               0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=               0
# ...                                                      ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=               1
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=               0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=               0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=               0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=               1
#
#                                               plan_duration_last  credit_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                31.0            0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                31.0            0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                31.0            0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                31.0            0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                30.0            0
# ...                                                          ...          ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                90.0            0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                31.0            0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                31.0            0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=               100.0            0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                 0.0            0
#
#                                               days_since_last_transaction_date_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                                   45.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                                   34.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                                   45.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                                   40.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                                   36.0
# ...                                                                             ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                                  110.0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                                   34.0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                                   42.0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                                  130.0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                                   27.0
#
#                                               days_since_membership_expire_date_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                                    14.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                                     3.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                                    14.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                                     9.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                                     6.0
# ...                                                                              ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                                    20.0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                                     3.0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                                    11.0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                                    30.0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                                    27.0
#
#                                               expired_and_not_auto_renew_last
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                                0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                                0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                                0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                                0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                                1
# ...                                                                       ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                                0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                                0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                                0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                                1
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                                0
#
# [934533 rows x 10 columns]

# %%
df2 = transactions_mean_df[['msno'] + numerical_columns_mean].sort_values(by='msno').set_index('msno')
df2
# Out:
#                                               payment_plan_days_mean  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=               30.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=               28.800000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=               30.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=               30.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=               34.466667
# ...                                                              ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=               30.000000
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=               28.800000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=               30.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=               32.200000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=               30.000000
#
#                                               plan_list_price_mean  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=             99.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=            143.040000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=            149.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=            149.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=            160.933333
# ...                                                            ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=            112.750000
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=            117.040000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=             99.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=            143.200000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=             99.000000
#
#                                               actual_amount_paid_mean  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                99.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=               149.000000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=               149.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=               149.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=               160.933333
# ...                                                               ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=               112.750000
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=               123.000000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                99.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=               150.650000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                99.000000
#
#                                               is_auto_renew_mean  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 1.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                 1.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                 1.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                 1.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                 0.0
# ...                                                          ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                 1.0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                 1.0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                 1.0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                 0.0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                 1.0
#
#                                               is_cancel_mean  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=        0.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=        0.000000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=        0.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=        0.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=        0.000000
# ...                                                      ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=        0.083333
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=        0.040000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=        0.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=        0.000000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=        0.083333
#
#                                               plan_duration_mean  credit_mean  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=           30.333333         0.00
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=           30.480000         5.96
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=           30.636364         0.00
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=           30.636364         0.00
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=           36.666667         0.00
# ...                                                          ...          ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=          118.791667         0.00
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=           29.280000         5.96
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=           30.333333         0.00
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=           44.750000         7.45
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=           28.083333         0.00
#
#                                               days_since_last_transaction_date_mean  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                              75.333333
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                             400.320000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                             198.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                             193.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                             339.933333
# ...                                                                             ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                             446.500000
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                             379.280000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                              72.333333
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                             490.550000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                             193.833333
#
#                                               days_since_membership_expire_date_mean  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                               45.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                              369.840000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                              167.363636
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                              162.363636
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                              303.266667
# ...                                                                              ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                              327.708333
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                              350.000000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                               42.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                              445.800000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                              165.750000
#
#                                               expired_and_not_auto_renew_mean
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                              0.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                              0.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                              0.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                              0.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                              1.0
# ...                                                                       ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                              0.0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                              0.0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                              0.0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                              1.0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                              0.0
#
# [934533 rows x 10 columns]

# %%
transactions_dev_from_mean_df = df1 - df2.values
transactions_dev_from_mean_df
# Out:
#                                               payment_plan_days_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                0.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                1.200000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                0.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                0.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=               -4.466667
# ...                                                              ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                0.000000
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                1.200000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                0.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=               67.800000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                0.000000
#
#                                               plan_list_price_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=              0.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=              5.960000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=              0.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=              0.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=            -11.933333
# ...                                                            ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=            -13.750000
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=            -18.040000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=              0.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=            336.800000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=              0.000000
#
#                                               actual_amount_paid_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 0.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                 0.000000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                 0.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                 0.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=               -11.933333
# ...                                                               ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=               -13.750000
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=               -24.000000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                 0.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=               329.350000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                 0.000000
#
#                                               is_auto_renew_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 0.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                 0.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                 0.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                 0.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                 0.0
# ...                                                          ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                 0.0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                 0.0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                 0.0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                 0.0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                 0.0
#
#                                               is_cancel_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=        0.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=        0.000000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=        0.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=        0.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=        0.000000
# ...                                                      ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=        0.916667
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=       -0.040000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=        0.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=        0.000000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=        0.916667
#
#                                               plan_duration_last  credit_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=            0.666667         0.00
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=            0.520000        -5.96
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=            0.363636         0.00
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=            0.363636         0.00
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=           -6.666667         0.00
# ...                                                          ...          ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=          -28.791667         0.00
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=            1.720000        -5.96
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=            0.666667         0.00
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=           55.250000        -7.45
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=          -28.083333         0.00
#
#                                               days_since_last_transaction_date_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                             -30.333333
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                            -366.320000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                            -153.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                            -153.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                            -303.933333
# ...                                                                             ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                            -336.500000
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                            -345.280000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                             -30.333333
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                            -360.550000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                            -166.833333
#
#                                               days_since_membership_expire_date_last  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                              -31.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                             -366.840000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                             -153.363636
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                             -153.363636
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                             -297.266667
# ...                                                                              ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                             -307.708333
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                             -347.000000
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                              -31.000000
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                             -415.800000
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                             -138.750000
#
#                                               expired_and_not_auto_renew_last
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                              0.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                              0.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                              0.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                              0.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                              0.0
# ...                                                                       ...
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=                              0.0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                              0.0
# zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                              0.0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=                              0.0
# zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=                              0.0
#
# [934533 rows x 10 columns]

# %%
col_names = {'payment_plan_days_last':'payment_plan_days_dev',
             'plan_list_price_last':'plan_list_price_dev',
             'actual_amount_paid_last':'actual_amount_paid_dev',
             'is_auto_renew_last':'is_auto_renew_dev',
             'is_cancel_last':'is_cancel_dev',
             'plan_duration_last':'plan_duration_dev',
             'credit_last':'credit_dev',
             'days_since_last_transaction_date_last':'days_since_last_transaction_date_dev',
             'days_since_membership_expire_date_last':'days_since_membership_expire_date_dev',
             'expired_and_not_auto_renew_last':'expired_and_not_auto_renew_dev',
            }
transactions_dev_from_mean_df = transactions_dev_from_mean_df.rename(columns=col_names)
transactions_dev_from_mean_df.head()
# Out:
#                                               payment_plan_days_dev  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=               0.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=               1.200000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=               0.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=               0.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=              -4.466667
#
#                                               plan_list_price_dev  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=             0.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=             5.960000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=             0.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=             0.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=           -11.933333
#
#                                               actual_amount_paid_dev  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                0.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                0.000000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                0.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                0.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=              -11.933333
#
#                                               is_auto_renew_dev  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                0.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                0.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                0.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                0.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                0.0
#
#                                               is_cancel_dev  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=            0.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=            0.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=            0.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=            0.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=            0.0
#
#                                               plan_duration_dev  credit_dev  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=           0.666667        0.00
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=           0.520000       -5.96
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=           0.363636        0.00
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=           0.363636        0.00
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=          -6.666667        0.00
#
#                                               days_since_last_transaction_date_dev  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                            -30.333333
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                           -366.320000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                           -153.000000
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                           -153.000000
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                           -303.933333
#
#                                               days_since_membership_expire_date_dev  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                             -31.000000
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                            -366.840000
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                            -153.363636
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                            -153.363636
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                            -297.266667
#
#                                               expired_and_not_auto_renew_dev
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                             0.0
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                             0.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                             0.0
# ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                             0.0
# ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                             0.0

# %%
train = pd.read_pickle('Data/train_v2_scala_clean.pickle')

# %%
train.shape
# Out:
# (886500, 2)

# %%
train.head()
# Out:
#                                            msno  is_churn
# 0  ++4RuqBw0Ss6bQU4oMxaRlbBPoWzoEiIZaxPM04Y4+U=       0.0
# 1  +/HS8LzrRGXolKbxRzDLqrmwuXqPOYixBIPXkyNcKNI=       0.0
# 2  +/g9O3USecrC8npzaFHXW/2XJ7fB80SineiUoCg7M6o=       0.0
# 3  +/namlXq+u3izRjHCFJV4MgqcXcLidZYszVsROOq/y4=       0.0
# 4  +0/X9tkmyHyet9X80G6GTrDFHnJqvai8d1ZPhayT0os=       0.0

# %%
transactions_mar = pd.merge(train, last_transactions_df, on='msno', how='left')
transactions_mar = pd.merge(transactions_mar, transactions_sum_df, on='msno', how='left')
transactions_mar = pd.merge(transactions_mar, transactions_mean_df, on='msno', how='left')
transactions_mar = pd.merge(transactions_mar, transactions_dev_from_mean_df, on='msno', how='left')

# %%
transactions_mar.head()
# Out:
#                                            msno  is_churn  \
# 0  ++4RuqBw0Ss6bQU4oMxaRlbBPoWzoEiIZaxPM04Y4+U=       0.0
# 1  +/HS8LzrRGXolKbxRzDLqrmwuXqPOYixBIPXkyNcKNI=       0.0
# 2  +/g9O3USecrC8npzaFHXW/2XJ7fB80SineiUoCg7M6o=       0.0
# 3  +/namlXq+u3izRjHCFJV4MgqcXcLidZYszVsROOq/y4=       0.0
# 4  +0/X9tkmyHyet9X80G6GTrDFHnJqvai8d1ZPhayT0os=       0.0
#
#   payment_method_id_last  payment_plan_days_last  plan_list_price_last  \
# 0   payment_method_id_41                    30.0                 149.0
# 1   payment_method_id_40                    30.0                 149.0
# 2                    NaN                     NaN                   NaN
# 3   payment_method_id_34                    30.0                 149.0
# 4   payment_method_id_34                    30.0                 149.0
#
#    actual_amount_paid_last  is_auto_renew_last  transaction_date_last  \
# 0                    149.0                 1.0             20170113.0
# 1                    149.0                 1.0             20170117.0
# 2                      NaN                 NaN                    NaN
# 3                    149.0                 1.0             20170131.0
# 4                    149.0                 1.0             20170131.0
#
#    membership_expire_date_last  is_cancel_last  ... payment_plan_days_dev  \
# 0                   20170213.0             0.0  ...              1.200000
# 1                   20170216.0             0.0  ...              0.000000
# 2                          NaN             NaN  ...                   NaN
# 3                   20170228.0             0.0  ...              8.571429
# 4                   20170228.0             0.0  ...              8.571429
#
#   plan_list_price_dev actual_amount_paid_dev is_auto_renew_dev is_cancel_dev  \
# 0            9.960000                    4.8               0.0           0.0
# 1            0.000000                    0.0               0.0           0.0
# 2                 NaN                    NaN               NaN           NaN
# 3           42.571429                    0.0               0.0           0.0
# 4           42.571429                    0.0               0.0           0.0
#
#   plan_duration_dev  credit_dev  days_since_last_transaction_date_dev  \
# 0          0.520000   -5.160000                           -366.320000
# 1          0.333333    0.000000                           -122.444444
# 2               NaN         NaN                                   NaN
# 3         -2.428571  -42.571429                           -308.761905
# 4         -2.428571  -42.571429                           -308.761905
#
#    days_since_membership_expire_date_dev  expired_and_not_auto_renew_dev
# 0                            -366.840000                             0.0
# 1                            -122.777778                             0.0
# 2                                    NaN                             NaN
# 3                            -306.333333                             0.0
# 4                            -306.333333                             0.0
#
# [5 rows x 58 columns]

# %%
transactions_mar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 886500 entries, 0 to 886499
# Data columns (total 58 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   msno                                    886500 non-null  object
#  1   is_churn                                886500 non-null  float64
#  2   payment_method_id_last                  848480 non-null  object
#  3   payment_plan_days_last                  848480 non-null  float64
#  4   plan_list_price_last                    848480 non-null  float64
#  5   actual_amount_paid_last                 848480 non-null  float64
#  6   is_auto_renew_last                      848480 non-null  float64
#  7   transaction_date_last                   848480 non-null  float64
#  8   membership_expire_date_last             848480 non-null  float64
#  9   is_cancel_last                          848480 non-null  float64
#  10  transaction_date_dt_last                848480 non-null  datetime64[ns]
#  11  membership_expire_date_dt_last          848480 non-null  datetime64[ns]
#  12  transaction_date_day_last               848480 non-null  object
#  13  membership_expire_date_day_last         848480 non-null  object
#  14  transaction_date_month_last             848480 non-null  object
#  15  membership_expire_date_month_last       848480 non-null  object
#  16  transaction_date_year_last              848480 non-null  float64
#  17  membership_expire_date_year_last        848480 non-null  float64
#  18  plan_duration_last                      848480 non-null  float64
#  19  credit_last                             848480 non-null  float64
#  20  transaction_credit_last                 848480 non-null  object
#  21  days_since_last_transaction_date_last   848480 non-null  float64
#  22  days_since_membership_expire_date_last  848480 non-null  float64
#  23  expired_and_not_auto_renew_last         848480 non-null  float64
#  24  payment_plan_days_sum                   848480 non-null  float64
#  25  plan_list_price_sum                     848480 non-null  float64
#  26  actual_amount_paid_sum                  848480 non-null  float64
#  27  is_auto_renew_sum                       848480 non-null  float64
#  28  is_cancel_sum                           848480 non-null  float64
#  29  transaction_date_year_sum               848480 non-null  float64
#  30  membership_expire_date_year_sum         848480 non-null  float64
#  31  plan_duration_sum                       848480 non-null  float64
#  32  credit_sum                              848480 non-null  float64
#  33  expired_and_not_auto_renew_sum          848480 non-null  float64
#  34  overall_credit                          848480 non-null  object
#  35  paid_per_day                            848455 non-null  float64
#  36  transactions_count                      848480 non-null  float64
#  37  amount_paid_per_transaction             848480 non-null  float64
#  38  payment_plan_days_mean                  848480 non-null  float64
#  39  plan_list_price_mean                    848480 non-null  float64
#  40  actual_amount_paid_mean                 848480 non-null  float64
#  41  is_auto_renew_mean                      848480 non-null  float64
#  42  is_cancel_mean                          848480 non-null  float64
#  43  plan_duration_mean                      848480 non-null  float64
#  44  credit_mean                             848480 non-null  float64
#  45  days_since_last_transaction_date_mean   848480 non-null  float64
#  46  days_since_membership_expire_date_mean  848480 non-null  float64
#  47  expired_and_not_auto_renew_mean         848480 non-null  float64
#  48  payment_plan_days_dev                   848480 non-null  float64
#  49  plan_list_price_dev                     848480 non-null  float64
#  50  actual_amount_paid_dev                  848480 non-null  float64
#  51  is_auto_renew_dev                       848480 non-null  float64
#  52  is_cancel_dev                           848480 non-null  float64
#  53  plan_duration_dev                       848480 non-null  float64
#  54  credit_dev                              848480 non-null  float64
#  55  days_since_last_transaction_date_dev    848480 non-null  float64
#  56  days_since_membership_expire_date_dev   848480 non-null  float64
#  57  expired_and_not_auto_renew_dev          848480 non-null  float64
# dtypes: datetime64[ns](2), float64(48), object(8)
# memory usage: 399.0+ MB

# %%
transactions_mar.shape
# Out:
# (886500, 58)

# %%
import missingno as ms

ms.matrix(transactions_mar)
plt.tight_layout()
#plt.savefig('missing values.png')

# %%
import pickle

with open('Data/Processed/transactions_mar.pickle', 'wb') as handle:
    pickle.dump(transactions_mar, handle)
