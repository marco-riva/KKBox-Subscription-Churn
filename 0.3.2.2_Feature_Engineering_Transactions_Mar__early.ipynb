# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import matplotlib as mpl 
mpl.rcParams['figure.dpi'] = 400 # figure dots per inch
# %matplotlib inline

import seaborn as sns
sns.set()

from datetime import datetime, timedelta

# %%
# Load transactions (all data including March)  
transactions_df = pd.read_pickle('Data/transactions_clean.pickle')
transactions_df.head()
# Out:
#                                             msno  payment_method_id  \
# 1   AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# 10  bQkbrEPdMfVfdsoz0RoWSmgYpHJuhRqtIml7aRUrFL8=                 39
# 24  qNpZJ7gsMPAFSvc5V3kgqtFfUQU2SZe7XSUYOAfqtoA=                 40
# 26  WnxdSgeK3Vg4BIaioJQYilnL+E1SDxq+PZIwmmfTwgM=                 34
# 27  ir1jh/vWZ932FpSC2WeMxdOHQ+OkuUo3ZPQs8Ms4J9g=                 34
#
#     payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 1                  30              149                 149              1
# 10                 30              149                 149              1
# 24                 30              149                 149              1
# 26                  0                0                 149              1
# 27                  0                0                 149              1
#
#     transaction_date  membership_expire_date  is_cancel transaction_date_dt  \
# 1           20150930                20151031          0          2015-09-30
# 10          20150930                20151121          0          2015-09-30
# 24          20151001                20151101          0          2015-10-01
# 26          20150930                20151031          0          2015-09-30
# 27          20150930                20151031          0          2015-09-30
#
#    membership_expire_date_dt
# 1                 2015-10-31
# 10                2015-11-21
# 24                2015-11-01
# 26                2015-10-31
# 27                2015-10-31

# %% [markdown]
# Let's reduce high cardinality features:

# %%
payment_id_freq = transactions_df['payment_method_id'].value_counts(normalize=True)
payment_id_freq.round(4)
# Out:
# 41    0.6177
# 40    0.1105
# 38    0.0601
# 37    0.0536
# 34    0.0439
# 36    0.0399
# 33    0.0199
# 31    0.0147
# 39    0.0102
# 30    0.0062
# 29    0.0050
# 27    0.0030
# 35    0.0030
# 32    0.0026
# 28    0.0024
# 23    0.0021
# 18    0.0009
# 19    0.0008
# 14    0.0007
# 20    0.0007
# 16    0.0005
# 24    0.0004
# 22    0.0003
# 25    0.0003
# 26    0.0001
# 11    0.0001
# 13    0.0001
# 21    0.0001
# 17    0.0001
# 10    0.0001
# 12    0.0001
# 15    0.0000
# 8     0.0000
# 5     0.0000
# 6     0.0000
# 3     0.0000
# 2     0.0000
# 4     0.0000
# Name: payment_method_id, dtype: float64

# %%
# 80-20 rule - reduce cardinality
bottom_payment_id = payment_id_freq.quantile(q=0.8)
less_freq_payment_id = payment_id_freq[payment_id_freq <= bottom_payment_id]
less_freq_payment_id.round(4)
# Out:
# 39    0.0102
# 30    0.0062
# 29    0.0050
# 27    0.0030
# 35    0.0030
# 32    0.0026
# 28    0.0024
# 23    0.0021
# 18    0.0009
# 19    0.0008
# 14    0.0007
# 20    0.0007
# 16    0.0005
# 24    0.0004
# 22    0.0003
# 25    0.0003
# 26    0.0001
# 11    0.0001
# 13    0.0001
# 21    0.0001
# 17    0.0001
# 10    0.0001
# 12    0.0001
# 15    0.0000
# 8     0.0000
# 5     0.0000
# 6     0.0000
# 3     0.0000
# 2     0.0000
# 4     0.0000
# Name: payment_method_id, dtype: float64

# %%
transactions_df.loc[transactions_df['payment_method_id'].isin(less_freq_payment_id.index.tolist()), 'payment_method_id'] = 'other'
transactions_df['payment_method_id'] = transactions_df['payment_method_id'].apply(lambda x: "{}{}".format('payment_method_id_', x))
transactions_df['payment_method_id']
# Out:
# 1              payment_method_id_41
# 10          payment_method_id_other
# 24             payment_method_id_40
# 26             payment_method_id_34
# 27             payment_method_id_34
#                      ...
# 22962291       payment_method_id_36
# 22965803       payment_method_id_40
# 22965957       payment_method_id_40
# 22967796       payment_method_id_36
# 22974713       payment_method_id_40
# Name: payment_method_id, Length: 13664286, dtype: object

# %% [markdown]
# Let's also add some features:

# %%
transactions_df['plan_duration'] = (transactions_df['membership_expire_date_dt'] - 
                                  transactions_df['transaction_date_dt'])

transactions_df['plan_duration'] = transactions_df['plan_duration'].astype('timedelta64[D]')
transactions_df['plan_duration'].head()
# Out:
# 1     31.0
# 10    52.0
# 24    31.0
# 26    31.0
# 27    31.0
# Name: plan_duration, dtype: float64

# %%
transactions_df['plan_duration'].value_counts()
# Out:
#  31.0     5416123
#  30.0     4778706
#  29.0     1023662
#  32.0      900127
#  28.0      289981
#            ...
# -54.0           1
# -118.0          1
# -112.0          1
# -127.0          1
# -235.0          1
# Name: plan_duration, Length: 1070, dtype: int64

# %%
transactions_df[transactions_df['plan_duration'] < 0].head()
# Out:
#                                              msno        payment_method_id  \
# 422  Xik55GiZKTkU1fMHNuROOSIRjf67/9HQ9xYn7Ltldmk=  payment_method_id_other
# 482  ZcPtzHBvgbuQHg3Gx9O4+QX4LK+35NXZSyEUcIbL134=     payment_method_id_37
# 505  q7zVHl6rWbLoKUj3FCHSjO2caWkhhKskVfxPRyLBOHo=     payment_method_id_36
# 513  iEqhCo9ehvlVGXTEm02F4oSarbJUa3IWP13gRD7BFL0=     payment_method_id_36
# 550  sj2G673Oo9mUgQGg1zsN6Cxx6YmSWurMqaoNrsJ50DU=     payment_method_id_40
#
#      payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 422                 30              149                 149              1
# 482                 30              149                 149              1
# 505                 30              180                 180              1
# 513                 30              180                 180              1
# 550                 30              149                 149              1
#
#      transaction_date  membership_expire_date  is_cancel transaction_date_dt  \
# 422          20160225                20160224          1          2016-02-25
# 482          20160826                20160825          1          2016-08-26
# 505          20160908                20160907          1          2016-09-08
# 513          20170211                20170210          1          2017-02-11
# 550          20161225                20161224          1          2016-12-25
#
#     membership_expire_date_dt  plan_duration
# 422                2016-02-24           -1.0
# 482                2016-08-25           -1.0
# 505                2016-09-07           -1.0
# 513                2017-02-10           -1.0
# 550                2016-12-24           -1.0

# %%
transactions_df[transactions_df['plan_duration'] > 0].head()
# Out:
#                                             msno        payment_method_id  \
# 1   AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=     payment_method_id_41
# 10  bQkbrEPdMfVfdsoz0RoWSmgYpHJuhRqtIml7aRUrFL8=  payment_method_id_other
# 24  qNpZJ7gsMPAFSvc5V3kgqtFfUQU2SZe7XSUYOAfqtoA=     payment_method_id_40
# 26  WnxdSgeK3Vg4BIaioJQYilnL+E1SDxq+PZIwmmfTwgM=     payment_method_id_34
# 27  ir1jh/vWZ932FpSC2WeMxdOHQ+OkuUo3ZPQs8Ms4J9g=     payment_method_id_34
#
#     payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 1                  30              149                 149              1
# 10                 30              149                 149              1
# 24                 30              149                 149              1
# 26                  0                0                 149              1
# 27                  0                0                 149              1
#
#     transaction_date  membership_expire_date  is_cancel transaction_date_dt  \
# 1           20150930                20151031          0          2015-09-30
# 10          20150930                20151121          0          2015-09-30
# 24          20151001                20151101          0          2015-10-01
# 26          20150930                20151031          0          2015-09-30
# 27          20150930                20151031          0          2015-09-30
#
#    membership_expire_date_dt  plan_duration
# 1                 2015-10-31           31.0
# 10                2015-11-21           52.0
# 24                2015-11-01           31.0
# 26                2015-10-31           31.0
# 27                2015-10-31           31.0

# %% [markdown]
# Negative values in plan_duration imply the membership was canceled (is_canceled = 1).

# %%
transactions_df['credit'] = (transactions_df['actual_amount_paid'] - transactions_df['plan_list_price'])
transactions_df['credit'].value_counts()
# Out:
#  0       12883088
#  149       473082
# -30        202774
# -149        58159
#  119        17611
#  129        17348
#  150         4127
# -180         2002
# -20          1959
# -50          1155
#  894          742
#  134          623
#  100          469
#  1788         406
# -120          151
#  35           131
#  131          114
#  536           63
#  480           48
#  300           47
#  799           45
#  1599          40
#  30            27
#  450           13
#  447           10
#  930            9
#  1000           9
#  350            6
#  500            5
#  105            5
# -108            4
# -1              4
#  400            2
#  1150           2
#  760            1
#  50             1
#  41             1
# -699            1
#  12             1
#  1              1
# Name: credit, dtype: int64

# %%
transactions_df['transaction_credit'] = np.where(transactions_df['credit'] == 0, 
                                                 'even', 
                                                 np.where(transactions_df['credit'] > 0, 
                                                          'credit', 'debit'))

# %% [markdown]
# ## Generate Validation Set

# %% [markdown]
# Current day is March 1st, we consider members which exp date is in February and potentially churn in March.
# So transactions are until end of February - this will serve as validation dataset.

# %%
current_day = datetime(2017, 3, 1)
# transactions_df = transactions_df[(transactions_df['transaction_date_dt'] < current_day) &
#                                  (transactions_df['membership_expire_date_dt'] < current_day)].reset_index(drop=True)
transactions_df = transactions_df[(transactions_df['transaction_date_dt'] < current_day)].reset_index(drop=True)
transactions_df.head()
# Out:
#                                            msno        payment_method_id  \
# 0  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=     payment_method_id_41
# 1  bQkbrEPdMfVfdsoz0RoWSmgYpHJuhRqtIml7aRUrFL8=  payment_method_id_other
# 2  qNpZJ7gsMPAFSvc5V3kgqtFfUQU2SZe7XSUYOAfqtoA=     payment_method_id_40
# 3  WnxdSgeK3Vg4BIaioJQYilnL+E1SDxq+PZIwmmfTwgM=     payment_method_id_34
# 4  ir1jh/vWZ932FpSC2WeMxdOHQ+OkuUo3ZPQs8Ms4J9g=     payment_method_id_34
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              149                 149              1
# 1                 30              149                 149              1
# 2                 30              149                 149              1
# 3                  0                0                 149              1
# 4                  0                0                 149              1
#
#    transaction_date  membership_expire_date  is_cancel transaction_date_dt  \
# 0          20150930                20151031          0          2015-09-30
# 1          20150930                20151121          0          2015-09-30
# 2          20151001                20151101          0          2015-10-01
# 3          20150930                20151031          0          2015-09-30
# 4          20150930                20151031          0          2015-09-30
#
#   membership_expire_date_dt  plan_duration  credit transaction_credit
# 0                2015-10-31           31.0       0               even
# 1                2015-11-21           52.0       0               even
# 2                2015-11-01           31.0       0               even
# 3                2015-10-31           31.0     149             credit
# 4                2015-10-31           31.0     149             credit

# %%
transactions_df.shape
# Out:
# (13664092, 14)

# %%
transactions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13664092 entries, 0 to 13664091
# Data columns (total 14 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   msno                       object
#  1   payment_method_id          object
#  2   payment_plan_days          int16
#  3   plan_list_price            int16
#  4   actual_amount_paid         int16
#  5   is_auto_renew              int16
#  6   transaction_date           int64
#  7   membership_expire_date     int64
#  8   is_cancel                  int16
#  9   transaction_date_dt        datetime64[ns]
#  10  membership_expire_date_dt  datetime64[ns]
#  11  plan_duration              float64
#  12  credit                     int16
#  13  transaction_credit         object
# dtypes: datetime64[ns](2), float64(1), int16(6), int64(2), object(3)
# memory usage: 990.4+ MB

# %%
transactions_df.describe()
# Out:
#        payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# count       1.366409e+07     1.366409e+07        1.366409e+07   1.366409e+07
# mean        2.992232e+01     1.317256e+02        1.362604e+02   9.046988e-01
# std         1.756205e+01     7.888564e+01        7.586591e+01   2.936305e-01
# min         0.000000e+00     0.000000e+00        0.000000e+00   0.000000e+00
# 25%         3.000000e+01     9.900000e+01        9.900000e+01   1.000000e+00
# 50%         3.000000e+01     1.490000e+02        1.490000e+02   1.000000e+00
# 75%         3.000000e+01     1.490000e+02        1.490000e+02   1.000000e+00
# max         4.500000e+02     2.000000e+03        2.000000e+03   1.000000e+00
#
#        transaction_date  membership_expire_date     is_cancel  plan_duration  \
# count      1.366409e+07            1.366409e+07  1.366409e+07   1.366409e+07
# mean       2.015808e+07            2.015916e+07  1.787320e-02   3.444530e+01
# std        5.617442e+03            6.083026e+03  1.324906e-01   3.742648e+01
# min        2.015010e+07            2.015010e+07  0.000000e+00  -3.570000e+02
# 25%        2.015103e+07            2.015121e+07  0.000000e+00   3.000000e+01
# 50%        2.016050e+07            2.016061e+07  0.000000e+00   3.100000e+01
# 75%        2.016093e+07            2.016103e+07  0.000000e+00   3.100000e+01
# max        2.017023e+07            2.017023e+07  1.000000e+00   7.830000e+02
#
#              credit
# count  1.366409e+07
# mean   4.534807e+00
# std    3.257363e+01
# min   -6.990000e+02
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.788000e+03

# %%
transactions_df['days_since_last_transaction_date'] = current_day - transactions_df['transaction_date_dt']
transactions_df['days_since_last_transaction_date'] = transactions_df['days_since_last_transaction_date'].astype('timedelta64[D]')
transactions_df['days_since_membership_expire_date'] = current_day - transactions_df['membership_expire_date_dt']
transactions_df['days_since_membership_expire_date'] = transactions_df['days_since_membership_expire_date'].astype('timedelta64[D]')

# %%
transactions_df[['msno',
                 'transaction_date_dt', 
                 'days_since_last_transaction_date',
                 'membership_expire_date_dt', 
                 'days_since_membership_expire_date',
                 'is_auto_renew']].sort_values(by='msno').head()
# Out:
#                                                   msno transaction_date_dt  \
# 37103     +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=          2017-01-15
# 11365513  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=          2016-12-15
# 950309    +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=          2016-11-16
# 1834581   +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=          2016-07-26
# 10438013  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=          2015-04-26
#
#           days_since_last_transaction_date membership_expire_date_dt  \
# 37103                                 45.0                2017-02-15
# 11365513                              76.0                2017-01-15
# 950309                               105.0                2016-12-15
# 1834581                              218.0                2016-08-26
# 10438013                             675.0                2015-05-26
#
#           days_since_membership_expire_date  is_auto_renew
# 37103                                  14.0              1
# 11365513                               45.0              1
# 950309                                 76.0              1
# 1834581                               187.0              1
# 10438013                              645.0              1

# %%
transactions_df['expired_and_not_auto_renew'] = np.where(
    (transactions_df.is_auto_renew == 0) & (transactions_df.days_since_membership_expire_date > 0), 1, 0
).astype(np.int8)
transactions_df['expired_and_not_auto_renew'].value_counts()
# Out:
# 0    12361888
# 1     1302204
# Name: expired_and_not_auto_renew, dtype: int64

# %% [markdown]
# Create features summarizing the last transaction:

# %%
transactions_df_sorted = transactions_df.sort_values(['msno','membership_expire_date_dt'], ascending=False).reset_index(drop = True)
transactions_df_sorted
# Out:
#                                                   msno     payment_method_id  \
# 0         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# 1         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# 2         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# 3         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# 4         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=  payment_method_id_41
# ...                                                ...                   ...
# 13664087  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=  payment_method_id_41
# 13664088  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=  payment_method_id_41
# 13664089  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=  payment_method_id_41
# 13664090  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=  payment_method_id_41
# 13664091  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=  payment_method_id_41
#
#           payment_plan_days  plan_list_price  actual_amount_paid  \
# 0                        30               99                  99
# 1                        30               99                  99
# 2                        30               99                  99
# 3                        30               99                  99
# 4                        30               99                  99
# ...                     ...              ...                 ...
# 13664087                 30              149                 149
# 13664088                 30              149                 149
# 13664089                 30               99                  99
# 13664090                 30               99                  99
# 13664091                 30               99                  99
#
#           is_auto_renew  transaction_date  membership_expire_date  is_cancel  \
# 0                     1          20170104                20170204          0
# 1                     1          20170202                20170202          1
# 2                     1          20161204                20170104          0
# 3                     1          20161104                20161204          0
# 4                     1          20161004                20161104          0
# ...                 ...               ...                     ...        ...
# 13664087              1          20150226                20150326          0
# 13664088              1          20150126                20150226          0
# 13664089              1          20170115                20170215          0
# 13664090              1          20161215                20170115          0
# 13664091              1          20161116                20161215          0
#
#          transaction_date_dt membership_expire_date_dt  plan_duration  credit  \
# 0                 2017-01-04                2017-02-04           31.0       0
# 1                 2017-02-02                2017-02-02            0.0       0
# 2                 2016-12-04                2017-01-04           31.0       0
# 3                 2016-11-04                2016-12-04           30.0       0
# 4                 2016-10-04                2016-11-04           31.0       0
# ...                      ...                       ...            ...     ...
# 13664087          2015-02-26                2015-03-26           28.0       0
# 13664088          2015-01-26                2015-02-26           31.0       0
# 13664089          2017-01-15                2017-02-15           31.0       0
# 13664090          2016-12-15                2017-01-15           31.0       0
# 13664091          2016-11-16                2016-12-15           29.0       0
#
#          transaction_credit  days_since_last_transaction_date  \
# 0                      even                              56.0
# 1                      even                              27.0
# 2                      even                              87.0
# 3                      even                             117.0
# 4                      even                             148.0
# ...                     ...                               ...
# 13664087               even                             734.0
# 13664088               even                             765.0
# 13664089               even                              45.0
# 13664090               even                              76.0
# 13664091               even                             105.0
#
#           days_since_membership_expire_date  expired_and_not_auto_renew
# 0                                      25.0                           0
# 1                                      27.0                           0
# 2                                      56.0                           0
# 3                                      87.0                           0
# 4                                     117.0                           0
# ...                                     ...                         ...
# 13664087                              706.0                           0
# 13664088                              734.0                           0
# 13664089                               14.0                           0
# 13664090                               45.0                           0
# 13664091                               76.0                           0
#
# [13664092 rows x 17 columns]

# %%
last_transactions_df = transactions_df_sorted.drop_duplicates(subset='msno', keep='first')
last_transactions_df.columns = last_transactions_df.columns + '_last'
last_transactions_df = last_transactions_df.rename(columns={'msno_last': 'msno'})
last_transactions_df
# Out:
#                                                   msno  \
# 0         zzzN9thH22os1dRS0VHReY/8FTfGHOi86//d+wGGFsQ=
# 12        zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=
# 32        zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=
# 35        zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=
# 60        zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=
# ...                                                ...
# 13664027  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=
# 13664042  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=
# 13664053  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=
# 13664064  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=
# 13664089  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=
#
#            payment_method_id_last  payment_plan_days_last  \
# 0            payment_method_id_41                      30
# 12        payment_method_id_other                     100
# 32           payment_method_id_41                      30
# 35           payment_method_id_41                      30
# 60           payment_method_id_41                      30
# ...                           ...                     ...
# 13664027     payment_method_id_38                      30
# 13664042     payment_method_id_41                      30
# 13664053     payment_method_id_41                      30
# 13664064     payment_method_id_41                      30
# 13664089     payment_method_id_41                      30
#
#           plan_list_price_last  actual_amount_paid_last  is_auto_renew_last  \
# 0                           99                       99                   1
# 12                         480                      480                   0
# 32                          99                       99                   1
# 35                          99                       99                   1
# 60                          99                       99                   1
# ...                        ...                      ...                 ...
# 13664027                   149                      149                   0
# 13664042                   149                      149                   1
# 13664053                   149                      149                   1
# 13664064                   149                      149                   1
# 13664089                    99                       99                   1
#
#           transaction_date_last  membership_expire_date_last  is_cancel_last  \
# 0                      20170104                     20170204               0
# 12                     20161022                     20170130               0
# 32                     20170118                     20170218               0
# 35                     20170126                     20170226               0
# 60                     20161111                     20170209               1
# ...                         ...                          ...             ...
# 13664027               20170124                     20170223               0
# 13664042               20170120                     20170220               0
# 13664053               20170115                     20170215               0
# 13664064               20170126                     20170226               0
# 13664089               20170115                     20170215               0
#
#          transaction_date_dt_last membership_expire_date_dt_last  \
# 0                      2017-01-04                     2017-02-04
# 12                     2016-10-22                     2017-01-30
# 32                     2017-01-18                     2017-02-18
# 35                     2017-01-26                     2017-02-26
# 60                     2016-11-11                     2017-02-09
# ...                           ...                            ...
# 13664027               2017-01-24                     2017-02-23
# 13664042               2017-01-20                     2017-02-20
# 13664053               2017-01-15                     2017-02-15
# 13664064               2017-01-26                     2017-02-26
# 13664089               2017-01-15                     2017-02-15
#
#           plan_duration_last  credit_last transaction_credit_last  \
# 0                       31.0            0                    even
# 12                     100.0            0                    even
# 32                      31.0            0                    even
# 35                      31.0            0                    even
# 60                      90.0            0                    even
# ...                      ...          ...                     ...
# 13664027                30.0            0                    even
# 13664042                31.0            0                    even
# 13664053                31.0            0                    even
# 13664064                31.0            0                    even
# 13664089                31.0            0                    even
#
#           days_since_last_transaction_date_last  \
# 0                                          56.0
# 12                                        130.0
# 32                                         42.0
# 35                                         34.0
# 60                                        110.0
# ...                                         ...
# 13664027                                   36.0
# 13664042                                   40.0
# 13664053                                   45.0
# 13664064                                   34.0
# 13664089                                   45.0
#
#           days_since_membership_expire_date_last  \
# 0                                           25.0
# 12                                          30.0
# 32                                          11.0
# 35                                           3.0
# 60                                          20.0
# ...                                          ...
# 13664027                                     6.0
# 13664042                                     9.0
# 13664053                                    14.0
# 13664064                                     3.0
# 13664089                                    14.0
#
#           expired_and_not_auto_renew_last
# 0                                       0
# 12                                      1
# 32                                      0
# 35                                      0
# 60                                      0
# ...                                   ...
# 13664027                                1
# 13664042                                0
# 13664053                                0
# 13664064                                0
# 13664089                                0
#
# [934533 rows x 17 columns]

# %% [markdown]
# Let's create other features by grouping and aggregating:

# %%
transactions_sum_df = transactions_df.copy()
transactions_sum_df.columns
# Out:
# Index(['msno', 'payment_method_id', 'payment_plan_days', 'plan_list_price',
#        'actual_amount_paid', 'is_auto_renew', 'transaction_date',
#        'membership_expire_date', 'is_cancel', 'transaction_date_dt',
#        'membership_expire_date_dt', 'plan_duration', 'credit',
#        'transaction_credit', 'days_since_last_transaction_date',
#        'days_since_membership_expire_date', 'expired_and_not_auto_renew'],
#       dtype='object')

# %%
to_drop = ['transaction_date',
           'membership_expire_date', 
           'transaction_date_dt', 
           'membership_expire_date_dt',
           'days_since_last_transaction_date',
           'days_since_membership_expire_date',
           ]
transactions_sum_df.drop(to_drop, axis=1, inplace=True)

# %%
transactions_sum_df = transactions_sum_df.groupby('msno').sum().reset_index()
transactions_sum_df.columns = transactions_sum_df.columns + '_sum' 
transactions_sum_df = transactions_sum_df.rename(columns={'msno_sum': 'msno'})

# %%
transactions_sum_df['overall_credit'] = np.where(transactions_sum_df['credit_sum'] == 0, 
                                             'even', np.where(transactions_sum_df['credit_sum'] > 0, 
                                                              'credit', 'debit'))

# %%
transactions_sum_df.head()
# Out:
#                                            msno  payment_plan_days_sum  \
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                     90
# 1  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                    720
# 2  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                    330
# 3  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                    330
# 4  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                    517
#
#    plan_list_price_sum  actual_amount_paid_sum  is_auto_renew_sum  \
# 0                  297                     297                  3
# 1                 3576                    3725                 25
# 2                 1639                    1639                 11
# 3                 1639                    1639                 11
# 4                 2414                    2414                  0
#
#    is_cancel_sum  plan_duration_sum  credit_sum  \
# 0              0               91.0           0
# 1              0              762.0         149
# 2              0              337.0           0
# 3              0              337.0           0
# 4              0              550.0           0
#
#    expired_and_not_auto_renew_sum overall_credit
# 0                               0           even
# 1                               0         credit
# 2                               0           even
# 3                               0           even
# 4                              15           even

# %%
transactions_count_df = transactions_df.groupby('msno')['is_cancel'].count().reset_index()
transactions_count_df.rename(columns={'is_cancel': 'transactions_count'}, inplace=True)
transactions_count_df.head()
# Out:
#                                            msno  transactions_count
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                   3
# 1  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                  25
# 2  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                  11
# 3  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                  11
# 4  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                  15

# %%
transactions_mean_df = transactions_df.copy()
transactions_mean_df = transactions_mean_df.groupby('msno').mean().reset_index()
transactions_mean_df.columns = transactions_mean_df.columns + '_mean' 
transactions_mean_df = transactions_mean_df.rename(columns={'msno_mean': 'msno'})

transactions_mean_df.head()
# Out:
#                                            msno  payment_plan_days_mean  \
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=               30.000000
# 1  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=               28.800000
# 2  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=               30.000000
# 3  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=               30.000000
# 4  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=               34.466667
#
#    plan_list_price_mean  actual_amount_paid_mean  is_auto_renew_mean  \
# 0             99.000000                99.000000                 1.0
# 1            143.040000               149.000000                 1.0
# 2            149.000000               149.000000                 1.0
# 3            149.000000               149.000000                 1.0
# 4            160.933333               160.933333                 0.0
#
#    transaction_date_mean  membership_expire_date_mean  is_cancel_mean  \
# 0           2.016415e+07                 2.016718e+07             0.0
# 1           2.015625e+07                 2.015706e+07             0.0
# 2           2.016162e+07                 2.016252e+07             0.0
# 3           2.016162e+07                 2.016252e+07             0.0
# 4           2.015800e+07                 2.015929e+07             0.0
#
#    plan_duration_mean  credit_mean  days_since_last_transaction_date_mean  \
# 0           30.333333         0.00                              75.333333
# 1           30.480000         5.96                             400.320000
# 2           30.636364         0.00                             198.000000
# 3           30.636364         0.00                             193.000000
# 4           36.666667         0.00                             339.933333
#
#    days_since_membership_expire_date_mean  expired_and_not_auto_renew_mean
# 0                               45.000000                              0.0
# 1                              369.840000                              0.0
# 2                              167.363636                              0.0
# 3                              162.363636                              0.0
# 4                              303.266667                              1.0

# %%
transactions_median_df = transactions_df.copy()
transactions_median_df = transactions_median_df.groupby('msno').median().reset_index()
transactions_median_df.columns = transactions_median_df.columns + '_median' 
transactions_median_df = transactions_median_df.rename(columns={'msno_median': 'msno'})

transactions_median_df.head()
# Out:
#                                            msno  payment_plan_days_median  \
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                      30.0
# 1  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                      30.0
# 2  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=                      30.0
# 3  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=                      30.0
# 4  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=                      30.0
#
#    plan_list_price_median  actual_amount_paid_median  is_auto_renew_median  \
# 0                    99.0                       99.0                   1.0
# 1                   149.0                      149.0                   1.0
# 2                   149.0                      149.0                   1.0
# 3                   149.0                      149.0                   1.0
# 4                   149.0                      149.0                   0.0
#
#    transaction_date_median  membership_expire_date_median  is_cancel_median  \
# 0               20161215.0                     20170115.0               0.0
# 1               20160126.0                     20160226.0               0.0
# 2               20160815.0                     20160915.0               0.0
# 3               20160820.0                     20160920.0               0.0
# 4               20160320.0                     20160419.0               0.0
#
#    plan_duration_median  credit_median  \
# 0                  31.0            0.0
# 1                  31.0            0.0
# 2                  31.0            0.0
# 3                  31.0            0.0
# 4                  30.0            0.0
#
#    days_since_last_transaction_date_median  \
# 0                                     76.0
# 1                                    400.0
# 2                                    198.0
# 3                                    193.0
# 4                                    346.0
#
#    days_since_membership_expire_date_median  expired_and_not_auto_renew_median
# 0                                      45.0                                0.0
# 1                                     369.0                                0.0
# 2                                     167.0                                0.0
# 3                                     162.0                                0.0
# 4                                     316.0                                1.0

# %%
(last_transactions_df.shape, 
 transactions_sum_df.shape, 
 transactions_count_df.shape,
 transactions_mean_df.shape,
 transactions_median_df.shape)
# Out:
# ((934533, 17), (934533, 10), (934533, 2), (934533, 13), (934533, 13))

# %%
train = pd.read_pickle('Data/train_v2_scala_clean.pickle')

# %%
train.shape
# Out:
# (886500, 2)

# %%
train.head()
# Out:
#                                            msno  is_churn
# 0  ++4RuqBw0Ss6bQU4oMxaRlbBPoWzoEiIZaxPM04Y4+U=       0.0
# 1  +/HS8LzrRGXolKbxRzDLqrmwuXqPOYixBIPXkyNcKNI=       0.0
# 2  +/g9O3USecrC8npzaFHXW/2XJ7fB80SineiUoCg7M6o=       0.0
# 3  +/namlXq+u3izRjHCFJV4MgqcXcLidZYszVsROOq/y4=       0.0
# 4  +0/X9tkmyHyet9X80G6GTrDFHnJqvai8d1ZPhayT0os=       0.0

# %%
transactions_mar = pd.merge(train, last_transactions_df, on='msno', how='left')
transactions_mar = pd.merge(transactions_mar, transactions_sum_df, on='msno', how='left')
transactions_mar = pd.merge(transactions_mar, transactions_count_df, on='msno', how='left')
transactions_mar = pd.merge(transactions_mar, transactions_mean_df, on='msno', how='left')
transactions_mar = pd.merge(transactions_mar, transactions_median_df, on='msno', how='left')

# %%
transactions_mar.head()
# Out:
#                                            msno  is_churn  \
# 0  ++4RuqBw0Ss6bQU4oMxaRlbBPoWzoEiIZaxPM04Y4+U=       0.0
# 1  +/HS8LzrRGXolKbxRzDLqrmwuXqPOYixBIPXkyNcKNI=       0.0
# 2  +/g9O3USecrC8npzaFHXW/2XJ7fB80SineiUoCg7M6o=       0.0
# 3  +/namlXq+u3izRjHCFJV4MgqcXcLidZYszVsROOq/y4=       0.0
# 4  +0/X9tkmyHyet9X80G6GTrDFHnJqvai8d1ZPhayT0os=       0.0
#
#   payment_method_id_last  payment_plan_days_last  plan_list_price_last  \
# 0   payment_method_id_41                    30.0                 149.0
# 1   payment_method_id_40                    30.0                 149.0
# 2                    NaN                     NaN                   NaN
# 3   payment_method_id_34                    30.0                 149.0
# 4   payment_method_id_34                    30.0                 149.0
#
#    actual_amount_paid_last  is_auto_renew_last  transaction_date_last  \
# 0                    149.0                 1.0             20170113.0
# 1                    149.0                 1.0             20170117.0
# 2                      NaN                 NaN                    NaN
# 3                    149.0                 1.0             20170131.0
# 4                    149.0                 1.0             20170131.0
#
#    membership_expire_date_last  is_cancel_last  ... actual_amount_paid_median  \
# 0                   20170213.0             0.0  ...                     149.0
# 1                   20170216.0             0.0  ...                     149.0
# 2                          NaN             NaN  ...                       NaN
# 3                   20170228.0             0.0  ...                     149.0
# 4                   20170228.0             0.0  ...                     149.0
#
#   is_auto_renew_median  transaction_date_median  \
# 0                  1.0               20160113.0
# 1                  1.0               20160917.0
# 2                  NaN                      NaN
# 3                  1.0               20160331.0
# 4                  1.0               20160331.0
#
#    membership_expire_date_median is_cancel_median  plan_duration_median  \
# 0                     20160213.0              0.0                  31.0
# 1                     20161016.0              0.0                  30.0
# 2                            NaN              NaN                   NaN
# 3                     20160430.0              0.0                  31.0
# 4                     20160430.0              0.0                  31.0
#
#    credit_median  days_since_last_transaction_date_median  \
# 0            0.0                                    413.0
# 1            0.0                                    165.0
# 2            NaN                                      NaN
# 3            0.0                                    335.0
# 4            0.0                                    335.0
#
#    days_since_membership_expire_date_median  expired_and_not_auto_renew_median
# 0                                     382.0                                0.0
# 1                                     136.0                                0.0
# 2                                       NaN                                NaN
# 3                                     305.0                                0.0
# 4                                     305.0                                0.0
#
# [5 rows x 52 columns]

# %%
transactions_mar.shape
# Out:
# (886500, 52)

# %%
import missingno as ms

ms.matrix(transactions_mar)
plt.tight_layout()
#plt.savefig('missing values.png')

# %%
import pickle

with open('Data/Processed/transactions_mar.pickle', 'wb') as handle:
    pickle.dump(transactions_mar, handle)
